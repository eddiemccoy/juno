# %%
using Pkg
Pkg.add("Plots")
# Out:
#   Updating registry at `C:\Users\adil.yilmaz\.julia\registries\General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 %Fetching: [==>                                      ]  4.5 % [====>                                    ]  8.9 %4 %===========>                             ]  26.5 %                            ]  29.8 % %40.1 %.7 %>                 ]  55.2 %58.8 %Fetching: [==========================>              ]  64.3 %1 % %        ]  78.3 %.1 % % Resolving package versions...
#  Installed PlotThemes ───────── v0.3.0
#  Installed Missings ─────────── v0.4.1
#  Installed RecipesBase ──────── v0.7.0
#  Installed FFMPEG ───────────── v0.2.1
#  Installed ColorTypes ───────── v0.8.0
#  Installed Plots ────────────── v0.26.0
#  Installed JSON ─────────────── v0.21.0
#  Installed Requires ─────────── v0.5.2
#  Installed SortingAlgorithms ── v0.3.1
#  Installed Showoff ──────────── v0.3.1
# ...

# %%
using Plots
ts_length=100
values=randn(ts_length)
plot(values,color="blue")
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1186
# ┌ Warning: On Windows, creating file symlinks requires Administrator privileges
# └ @ Base.Filesystem file.jl:794
# ┌ Warning: On Windows, creating file symlinks requires Administrator privileges
# └ @ Base.Filesystem file.jl:794
# ┌ Warning: On Windows, creating file symlinks requires Administrator privileges
# └ @ Base.Filesystem file.jl:794

# %%
typeof(values)
# Out:
# Array{Float64,1}

# %%
x=[10,"foo",false]
# Out:
# 3-element Array{Any,1}:
#     10
#       "foo"
#  false

# %%
push!(x,"bar")
# Out:
# 3-element Array{Any,1}:
#  10
#    "foo"
#    "bar"

# %%
ts_length=100
_values=Array{Float64,1}(undef,ts_length)
for i in 1:ts_length
    _values[i]=randn()
end
plot(_values,color="blue")

# %%
P_A=
